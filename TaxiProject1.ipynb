# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# **This notebook is using the New York Taxi Fare Dataset taken from the playground competition, hosted in partnership with Google Cloud and Coursera, tasked for predicting the fare amount (inclusive of tolls) for a taxi ride in New York City given the pickup and dropoff locations.**

# %% [markdown]
# **Predicted the Fare price with the help of the given data using the simple Linear Regression algorithm.**

# %%
import numpy as np
import pandas as pd
import plotly

import matplotlib.pyplot as plt
import seaborn as sns

palette = sns.color_palette("rainbow", 8)


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Data Exploration
#
# <div style="background:#ffbf00; height:3px; width:70%; margin-left:-10px"></div>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Premalatha-success/Datasets/main/TaxiFare.csv')

# %%
df.shape
# Out:
# (50000, 8)

# %%
df.head(10).style.set_properties(**{'background-color': '#ffe100','color': '#000','border': '1px solid #000000'})
# Out:
# <style type="text/css">
# #T_d69cc_row0_col0, #T_d69cc_row0_col1, #T_d69cc_row0_col2, #T_d69cc_row0_col3, #T_d69cc_row0_col4, #T_d69cc_row0_col5, #T_d69cc_row0_col6, #T_d69cc_row0_col7, #T_d69cc_row1_col0, #T_d69cc_row1_col1, #T_d69cc_row1_col2, #T_d69cc_row1_col3, #T_d69cc_row1_col4, #T_d69cc_row1_col5, #T_d69cc_row1_col6, #T_d69cc_row1_col7, #T_d69cc_row2_col0, #T_d69cc_row2_col1, #T_d69cc_row2_col2, #T_d69cc_row2_col3, #T_d69cc_row2_col4, #T_d69cc_row2_col5, #T_d69cc_row2_col6, #T_d69cc_row2_col7, #T_d69cc_row3_col0, #T_d69cc_row3_col1, #T_d69cc_row3_col2, #T_d69cc_row3_col3, #T_d69cc_row3_col4, #T_d69cc_row3_col5, #T_d69cc_row3_col6, #T_d69cc_row3_col7, #T_d69cc_row4_col0, #T_d69cc_row4_col1, #T_d69cc_row4_col2, #T_d69cc_row4_col3, #T_d69cc_row4_col4, #T_d69cc_row4_col5, #T_d69cc_row4_col6, #T_d69cc_row4_col7, #T_d69cc_row5_col0, #T_d69cc_row5_col1, #T_d69cc_row5_col2, #T_d69cc_row5_col3, #T_d69cc_row5_col4, #T_d69cc_row5_col5, #T_d69cc_row5_col6, #T_d69cc_row5_col7, #T_d69cc_row6_col0, #T_d69cc_row6_col1, #T_d69cc_row6_col2, #T_d69cc_row6_col3, #T_d69cc_row6_col4, #T_d69cc_row6_col5, #T_d69cc_row6_col6, #T_d69cc_row6_col7, #T_d69cc_row7_col0, #T_d69cc_row7_col1, #T_d69cc_row7_col2, #T_d69cc_row7_col3, #T_d69cc_row7_col4, #T_d69cc_row7_col5, #T_d69cc_row7_col6, #T_d69cc_row7_col7, #T_d69cc_row8_col0, #T_d69cc_row8_col1, #T_d69cc_row8_col2, #T_d69cc_row8_col3, #T_d69cc_row8_col4, #T_d69cc_row8_col5, #T_d69cc_row8_col6, #T_d69cc_row8_col7, #T_d69cc_row9_col0, #T_d69cc_row9_col1, #T_d69cc_row9_col2, #T_d69cc_row9_col3, #T_d69cc_row9_col4, #T_d69cc_row9_col5, #T_d69cc_row9_col6, #T_d69cc_row9_col7 {
#   background-color: #ffe100;
#   color: #000;
#   border: 1px solid #000000;
# }
# </style>
# <table id="T_d69cc_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >unique_id</th>
#       <th class="col_heading level0 col1" >amount</th>
#       <th class="col_heading level0 col2" >date_time_of_pickup</th>
#       <th class="col_heading level0 col3" >longitude_of_pickup</th>
#       <th class="col_heading level0 col4" >latitude_of_pickup</th>
#       <th class="col_heading level0 col5" >longitude_of_dropoff</th>
#       <th class="col_heading level0 col6" >latitude_of_dropoff</th>
#       <th class="col_heading level0 col7" >no_of_passenger</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d69cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d69cc_row0_col0" class="data row0 col0" >26:21.0</td>
#       <td id="T_d69cc_row0_col1" class="data row0 col1" >4.500000</td>
#       <td id="T_d69cc_row0_col2" class="data row0 col2" >2009-06-15 17:26:21 UTC</td>
#       <td id="T_d69cc_row0_col3" class="data row0 col3" >-73.844311</td>
#       <td id="T_d69cc_row0_col4" class="data row0 col4" >40.721319</td>
#       <td id="T_d69cc_row0_col5" class="data row0 col5" >-73.841610</td>
#       <td id="T_d69cc_row0_col6" class="data row0 col6" >40.712278</td>
#       <td id="T_d69cc_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d69cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d69cc_row1_col0" class="data row1 col0" >52:16.0</td>
#       <td id="T_d69cc_row1_col1" class="data row1 col1" >16.900000</td>
#       <td id="T_d69cc_row1_col2" class="data row1 col2" >2010-01-05 16:52:16 UTC</td>
#       <td id="T_d69cc_row1_col3" class="data row1 col3" >-74.016048</td>
#       <td id="T_d69cc_row1_col4" class="data row1 col4" >40.711303</td>
#       <td id="T_d69cc_row1_col5" class="data row1 col5" >-73.979268</td>
#       <td id="T_d69cc_row1_col6" class="data row1 col6" >40.782004</td>
#       <td id="T_d69cc_row1_col7" class="data row1 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d69cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d69cc_row2_col0" class="data row2 col0" >35:00.0</td>
#       <td id="T_d69cc_row2_col1" class="data row2 col1" >5.700000</td>
#       <td id="T_d69cc_row2_col2" class="data row2 col2" >2011-08-18 00:35:00 UTC</td>
#       <td id="T_d69cc_row2_col3" class="data row2 col3" >-73.982738</td>
#       <td id="T_d69cc_row2_col4" class="data row2 col4" >40.761270</td>
#       <td id="T_d69cc_row2_col5" class="data row2 col5" >-73.991242</td>
#       <td id="T_d69cc_row2_col6" class="data row2 col6" >40.750562</td>
#       <td id="T_d69cc_row2_col7" class="data row2 col7" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d69cc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d69cc_row3_col0" class="data row3 col0" >30:42.0</td>
#       <td id="T_d69cc_row3_col1" class="data row3 col1" >7.700000</td>
#       <td id="T_d69cc_row3_col2" class="data row3 col2" >2012-04-21 04:30:42 UTC</td>
#       <td id="T_d69cc_row3_col3" class="data row3 col3" >-73.987130</td>
#       <td id="T_d69cc_row3_col4" class="data row3 col4" >40.733143</td>
#       <td id="T_d69cc_row3_col5" class="data row3 col5" >-73.991567</td>
#       <td id="T_d69cc_row3_col6" class="data row3 col6" >40.758092</td>
#       <td id="T_d69cc_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d69cc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d69cc_row4_col0" class="data row4 col0" >51:00.0</td>
#       <td id="T_d69cc_row4_col1" class="data row4 col1" >5.300000</td>
#       <td id="T_d69cc_row4_col2" class="data row4 col2" >2010-03-09 07:51:00 UTC</td>
#       <td id="T_d69cc_row4_col3" class="data row4 col3" >-73.968095</td>
#       <td id="T_d69cc_row4_col4" class="data row4 col4" >40.768008</td>
#       <td id="T_d69cc_row4_col5" class="data row4 col5" >-73.956655</td>
#       <td id="T_d69cc_row4_col6" class="data row4 col6" >40.783762</td>
#       <td id="T_d69cc_row4_col7" class="data row4 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d69cc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d69cc_row5_col0" class="data row5 col0" >50:45.0</td>
#       <td id="T_d69cc_row5_col1" class="data row5 col1" >12.100000</td>
#       <td id="T_d69cc_row5_col2" class="data row5 col2" >2011-01-06 09:50:45 UTC</td>
#       <td id="T_d69cc_row5_col3" class="data row5 col3" >-74.000964</td>
#       <td id="T_d69cc_row5_col4" class="data row5 col4" >40.731630</td>
#       <td id="T_d69cc_row5_col5" class="data row5 col5" >-73.972892</td>
#       <td id="T_d69cc_row5_col6" class="data row5 col6" >40.758233</td>
#       <td id="T_d69cc_row5_col7" class="data row5 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d69cc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d69cc_row6_col0" class="data row6 col0" >35:00.0</td>
#       <td id="T_d69cc_row6_col1" class="data row6 col1" >7.500000</td>
#       <td id="T_d69cc_row6_col2" class="data row6 col2" >2012-11-20 20:35:00 UTC</td>
#       <td id="T_d69cc_row6_col3" class="data row6 col3" >-73.980002</td>
#       <td id="T_d69cc_row6_col4" class="data row6 col4" >40.751662</td>
#       <td id="T_d69cc_row6_col5" class="data row6 col5" >-73.973802</td>
#       <td id="T_d69cc_row6_col6" class="data row6 col6" >40.764842</td>
#       <td id="T_d69cc_row6_col7" class="data row6 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d69cc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d69cc_row7_col0" class="data row7 col0" >22:00.0</td>
#       <td id="T_d69cc_row7_col1" class="data row7 col1" >16.500000</td>
#       <td id="T_d69cc_row7_col2" class="data row7 col2" >2012-01-04 17:22:00 UTC</td>
#       <td id="T_d69cc_row7_col3" class="data row7 col3" >-73.951300</td>
#       <td id="T_d69cc_row7_col4" class="data row7 col4" >40.774138</td>
#       <td id="T_d69cc_row7_col5" class="data row7 col5" >-73.990095</td>
#       <td id="T_d69cc_row7_col6" class="data row7 col6" >40.751048</td>
#       <td id="T_d69cc_row7_col7" class="data row7 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d69cc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d69cc_row8_col0" class="data row8 col0" >10:00.0</td>
#       <td id="T_d69cc_row8_col1" class="data row8 col1" >9.000000</td>
#       <td id

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unique_id             50000 non-null  object
#  1   amount                50000 non-null  float64
#  2   date_time_of_pickup   50000 non-null  object
#  3   longitude_of_pickup   50000 non-null  float64
#  4   latitude_of_pickup    50000 non-null  float64
#  5   longitude_of_dropoff  50000 non-null  float64
#  6   latitude_of_dropoff   50000 non-null  float64
#  7   no_of_passenger       50000 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.1+ MB

# %%
df.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  50000.000000         50000.000000        50000.000000
# mean      11.364171           -72.509756           39.933759
# std        9.685557            10.393860            6.224857
# min       -5.000000           -75.423848          -74.006893
# 25%        6.000000           -73.992062           40.734880
# 50%        8.500000           -73.981840           40.752678
# 75%       12.500000           -73.967148           40.767360
# max      200.000000            40.783472          401.083332
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# count          50000.000000         50000.000000     50000.000000
# mean             -72.504616            39.926251         1.667840
# std               10.407570             6.014737         1.289195
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991152            40.734372         1.000000
# 50%              -73.980082            40.753372         1.000000
# 75%              -73.963584            40.768167         2.000000
# max               40.851027            43.415190         6.000000

# %%
df.isnull().sum()
# Out:
# unique_id               0
# amount                  0
# date_time_of_pickup     0
# longitude_of_pickup     0
# latitude_of_pickup      0
# longitude_of_dropoff    0
# latitude_of_dropoff     0
# no_of_passenger         0
# dtype: int64

# %% [markdown]
# <a id="FEng"></a>
# <div style="background: #ffbf00; height:65px; width:65px; margin:0 0 -70px -10px;"></div>
# <div style="background:url('https://media.tenor.com/PjcIPM1Ba00AAAAi/tf2-tf2dance.gif') no-repeat; height:60px; margin-bottom:-65px; background-size:contain; background-position:right"></div>
#
# ## 2. Feature Enginnering
# <div style="background:#ffbf00; height:3px; width:70%; margin-left:-10px"></div>
#
# <br>
# <a id="rndsample"></a>
# <div style="background: #ffbf00; height:30px; width:50%; margin:0 0 -50px -10px;"></div>

# %% [markdown]
# **2.1 - Let get random sample of 10000**

# %%
rn_sample_df = df.sample(10000)

# %% [markdown]
# **2.2 - Seprate date, time and hour from the pickup time**

# %%
rn_sample_df['date_time_of_pickup'] = pd.to_datetime(rn_sample_df['date_time_of_pickup'], format= "%Y-%m-%d %H:%M:%S UTC")

rn_sample_df['year'] = rn_sample_df.date_time_of_pickup.apply(lambda t: t.year)
rn_sample_df['weekday'] = rn_sample_df.date_time_of_pickup.apply(lambda t: t.weekday())
rn_sample_df['hour'] = rn_sample_df.date_time_of_pickup.apply(lambda t: t.hour)

# %%
def distance(lat1, lon1, lat2, lon2):
    
    p = 0.017453292519943295 # Pi/180
    a = 0.5 - np.cos((lat2 - lat1) * p)/2 + np.cos(lat1 * p) * np.cos(lat2 * p) * (1 - np.cos((lon2 - lon1) * p)) / 2
    return 0.6213712 * 12742 * np.arcsin(np.sqrt(a))

# %%
rn_sample_df['distance'] = distance(rn_sample_df.latitude_of_pickup, rn_sample_df.latitude_of_pickup, 
                                    rn_sample_df.latitude_of_dropoff, rn_sample_df.latitude_of_dropoff)

# %% [markdown]
# ## 3. Data Cleaning
# <div style="background:#ffbf00; height:3px; width:70%; margin-left:-10px;"></div>
# ​

# %% [markdown]
# 3.1 **Removing the coloumns with** <b><em>**null**</em></b> **values**
# Lets start with removing the null values from the <b><em>rn_sample_df</em></b> sample dataset

# %%
rn_sample_df = rn_sample_df.dropna()

# %% [markdown]
# 3.2  Removing the fareprice less than zero
# As we have already seen that the fare price is gone below zero using the dataset description, so now remove them

# %%
rn_sample_df = rn_sample_df[rn_sample_df.amount > 0]

# %% [markdown]
# 3.3 Removing the <em><b>distance(mile)</b></em> less than zero

# %%
rn_sample_df = rn_sample_df[rn_sample_df.distance > 0]

# %% [markdown]
# 3.4 Removing the <b><em>key and pickup_datetime</em></b> coloumn from the dataset
# As we already got the date and time from pickup_datetime, so now there is no need of key and pickup_datetime

# %%
# now removing the key and pickup_datetime coloumn from the dataset
rn_sample_df = rn_sample_df.drop(['unique_id', 'date_time_of_pickup'], axis=1)

# %% [markdown]
# ## 4. Data Visualisation
# <div style="background:#ffbf00; height:3px; width:70%; margin-left:-10px"></div>

# %%
rn_sample_df.head()
# Out:
#        amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 40101     7.4           -73.965740           40.758498            -73.951542
# 38352     6.0           -73.982068           40.773402            -73.974500
# 46385    11.5           -73.994800           40.750357            -73.984908
# 44921    10.9           -74.015972           40.717725            -73.989727
# 32217    15.3           -73.986312           40.756595            -73.965012
#
#        latitude_of_dropoff  no_of_passenger  year  weekday  hour  distance
# 40101            40.781178                1  2009        6    23  1.965717
# 38352            40.789992                4  2013        4    20  1.437792
# 46385            40.780922                6  2014        6    23  2.649186
# 44921            40.762245                1  2011        4     6  3.859262
# 32217            40.691927                5  2009        0     2  5.606296

# %% [markdown]
# 4.1 Visualize the <em><b>geospatial locations</b></em> for the <b><em>pickup</em></b> points

# %%
import plotly.express as px

# %% [markdown]
# 4.1 Visualize the <em><b>geospatial locations</b></em> for the <b><em>pickup</em></b> points

# %%
tPickup_fig = px.scatter_mapbox(rn_sample_df, lat='latitude_of_pickup', lon='longitude_of_pickup', hover_name='amount', hover_data=['amount'],
    color='amount',color_continuous_scale=px.colors.sequential.Agsunset, opacity=.05,
    center={'lat': 40.75, 'lon': 286.051}, 
    zoom=11,
    height=500,width=1180,
    mapbox_style="carto-positron", labels=None)
tPickup_fig.update_layout(margin={"r": 0, "t": 0, "l": 0, "b": 0}).update_coloraxes(showscale=False)
tPickup_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1d394b9f-f320-4bce-a9ff-fb9375523c09" class="plotly-graph-div" style="height:500px; width:1180px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d394b9f-f320-4bce-a9ff-fb9375523c09")) {                    Plotly.newPlot(                        "1d394b9f-f320-4bce-a9ff-fb9375523c09",                        [{"customdata":[[7.4],[6.0],[11.5],[10.9],[15.3],[36.83],[6.1],[5.0],[18.0],[12.0],[39.83],[4.5],[6.5],[3.5],[14.5],[17.0],[6.9],[4.5],[9.7],[10.5],[5.0],[8.5],[6.5],[4.5],[4.9],[23.3],[7.0],[7.7],[6.5],[4.5],[3.3],[17.5],[8.5],[15.3],[4.9],[7.0],[7.3],[11.7],[3.5],[4.5],[32.0],[7.7],[4.0],[12.5],[8.5],[6.1],[9.7],[9.7],[4.5],[13.3],[15.3],[8.1],[6.1],[12.0],[5.3],[23.0],[14.5],[5.7],[4.5],[6.1],[5.5],[3.7],[4.9],[14.5],[8.5],[6.9],[9.5],[8.5],[18.5],[5.5],[4.0],[9.3],[5.7],[12.0],[13.0],[26.9],[18.5],[23.5],[14.5],[8.1],[21.5],[3.5],[6.5],[13.0],[8.1],[13.3],[17.5],[9.7],[31.33],[3.7],[17.7],[5.0],[9.0],[12.5],[7.3],[10.0],[6.0],[7.5],[3.7],[8.1],[4.9],[21.7],[6.5],[9.3],[4.5],[10.1],[12.9],[26.5],[7.5],[5.3],[9.3],[4.9],[9.0],[15.5],[16.5],[4.5],[8.5],[7.7],[6.9],[9.5],[12.0],[8.0],[10.9],[13.5],[6.5],[4.0],[5.7],[8.5],[19.0],[5.4],[8.1],[57.54],[6.1],[6.1],[8.5],[10.5],[9.3],[49.8],[12.9],[5.3],[21.3],[22.5],[13.7],[46.33],[18.5],[15.0],[7.5],[7.0],[10.1],[15.3],[8.5],[8.5],[4.5],[8.5],[8.0],[5.7],[10.5],[4.5],[62.66],[5.5],[6.9],[5.0],[14.9],[57.33],[12.1],[4.9],[7.7],[8.1],[11.7],[17.3],[37.83],[8.1],[6.5],[11.7],[49.57],[27.0],[9.5],[11.3],[6.5],[12.1],[8.5],[11.7],[10.1],[4.1],[9.7],[7.5],[5.0],[8.5],[28.9],[12.1],[6.9],[12.5],[8.9],[6.9],[8.5],[5.7],[10.5],[6.9],[3.3],[21.0],[4.1],[5.3],[5.3],[6.1],[9.7],[7.0],[17.0],[3.3],[8.1],[3.5],[25.8],[5.7],[10.5],[7.5],[11.3],[7.7],[6.5],[4.1],[5.7],[7.0],[25.5],[56.8],[5.3],[45.0],[8.1],[5.7],[9.5],[8.5],[5.5],[8.1],[11.5],[6.5],[14.1],[15.7],[4.5],[20.9],[9.7],[11.0],[33.83],[7.3],[6.0],[14.5],[22.9],[9.5],[6.9],[6.5],[17.83],[6.5],[8.1],[17.0],[5.7],[17.0],[8.5],[18.1],[17.5],[10.5],[25.0],[6.0],[7.7],[6.5],[6.5],[11.0],[6.1],[5.0],[14.5],[5.7],[36.1],[12.1],[10.9],[10.5],[15.3],[6.5],[9.3],[6.5],[12.0],[6.0],[5.7],[10.1],[9.3],[22.1],[9.0],[12.5],[22.5],[10.1],[20.0],[9.0],[8.0],[11.7],[13.5],[5.5],[4.5],[7.3],[30.1],[13.0],[52.9],[16.1],[15.3],[13.5],[3.3],[3.5],[7.5],[6.0],[10.5],[6.1],[20.5],[8.1],[6.0],[6.5],[4.5],[14.5],[20.0],[4.1],[11.7],[8.1],[9.3],[7.7],[7.0],[17.3],[8.5],[5.7],[4.5],[12.5],[4.5],[12.9],[7.7],[8.5],[11.3],[4.6],[15.0],[31.0],[4.1],[14.1],[8.5],[4.9],[15.7],[15.5],[11.0],[35.33],[5.3],[57.33],[8.9],[8.5],[11.0],[15.5],[17.5],[3.7],[4.9],[6.5],[7.3],[12.5],[6.5],[4.9],[10.1],[7.5],[7.5],[6.0],[17.3],[9.7],[15.0],[4.5],[11.0],[6.5],[5.3],[4.9],[8.9],[6.5],[7.5],[39.8],[7.7],[4.5],[22.1],[20.5],[7.3],[7.7],[8.5],[4.1],[8.5],[12.5],[10.5],[6.1],[6.5],[5.0],[4.0],[8.1],[4.1],[8.0],[13.5],[5.7],[16.9],[7.5],[7.3],[6.5],[8.5],[4.5],[5.0],[4.5],[11.5],[42.04],[18.5],[38.9],[11.5],[7.5],[4.9],[10.0],[8.1],[9.5],[6.9],[6.5],[6.5],[8.1],[12.0],[4.5],[9.0],[15.87],[8.5],[10.0],[11.3],[6.5],[12.5],[7.3],[6.1],[13.3],[16.5],[17.3],[8.1],[7.3],[7.5],[8.5],[10.0],[3.3],[7.0],[12.1],[8.5],[7.5],[88.0],[26.25],[20.5],[8.5],[15.5],[6.9],[35.0],[9.5],[6.1],[8.9],[11.3],[3.7],[13.3],[8.9],[9.5],[12.0],[19.0],[8.9],[49.8],[8.9],[5.3],[9.7],[7.3],[6.1],[13.0],[7.0],[5.0],[20.1],[5.3],[28.5],[4.5],[12.1],[3.7],[9.3],[15.0],[12.5],[10.1],[7.0],[7.3],[7.5],[30.5],[8.5],[14.5],[18.5],[7.3],[9.7],[3.7],[4.0],[8.0],[10.5],[8.5],[9.5],[17.0],[7.7],[14.1],[16.9],[6.5],[22.5],[10.5],[7.7],[13.0],[13.0],[6.0],[5.7],[7.0],[3.7],[21.5],[7.5],[10.5],[6.5],[15.5],[6.1],[13.5],[23.5],[6.0],[5.3],[11.3],[14.5],[7.0],[6.9],[28.5],[7.3],[6.5],[4.5],[10.0],[15.0],[57.33],[17.0],[16.0],[27.0],[10.5],[11.5],[6.9],[15.0],[6.0],[12.9],[12.0],[5.0],[4.0],[13 ...

# %% [markdown]
# 4.2 Visualize the <em><b>geospatial locations</b></em> for the <em><b>dropoff</b></em> points

# %%
tDropoff_fig = px.scatter_mapbox(rn_sample_df, lat='latitude_of_dropoff', lon='longitude_of_dropoff', hover_name='amount', hover_data=['amount'],
    color='amount',color_continuous_scale=px.colors.sequential.Rainbow_r, opacity=0.1,
    center={'lat': 40.75, 'lon': 286.051},
    zoom=11,
    height=500,width=1180,
    mapbox_style="carto-positron", labels=None)
tDropoff_fig.update_layout(margin={"r": 0, "t": 0, "l": 0, "b": 0}).update_coloraxes(showscale=False)
tDropoff_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5a74f1a6-1aff-47a9-bc7f-f401b3a028d7" class="plotly-graph-div" style="height:500px; width:1180px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a74f1a6-1aff-47a9-bc7f-f401b3a028d7")) {                    Plotly.newPlot(                        "5a74f1a6-1aff-47a9-bc7f-f401b3a028d7",                        [{"customdata":[[7.4],[6.0],[11.5],[10.9],[15.3],[36.83],[6.1],[5.0],[18.0],[12.0],[39.83],[4.5],[6.5],[3.5],[14.5],[17.0],[6.9],[4.5],[9.7],[10.5],[5.0],[8.5],[6.5],[4.5],[4.9],[23.3],[7.0],[7.7],[6.5],[4.5],[3.3],[17.5],[8.5],[15.3],[4.9],[7.0],[7.3],[11.7],[3.5],[4.5],[32.0],[7.7],[4.0],[12.5],[8.5],[6.1],[9.7],[9.7],[4.5],[13.3],[15.3],[8.1],[6.1],[12.0],[5.3],[23.0],[14.5],[5.7],[4.5],[6.1],[5.5],[3.7],[4.9],[14.5],[8.5],[6.9],[9.5],[8.5],[18.5],[5.5],[4.0],[9.3],[5.7],[12.0],[13.0],[26.9],[18.5],[23.5],[14.5],[8.1],[21.5],[3.5],[6.5],[13.0],[8.1],[13.3],[17.5],[9.7],[31.33],[3.7],[17.7],[5.0],[9.0],[12.5],[7.3],[10.0],[6.0],[7.5],[3.7],[8.1],[4.9],[21.7],[6.5],[9.3],[4.5],[10.1],[12.9],[26.5],[7.5],[5.3],[9.3],[4.9],[9.0],[15.5],[16.5],[4.5],[8.5],[7.7],[6.9],[9.5],[12.0],[8.0],[10.9],[13.5],[6.5],[4.0],[5.7],[8.5],[19.0],[5.4],[8.1],[57.54],[6.1],[6.1],[8.5],[10.5],[9.3],[49.8],[12.9],[5.3],[21.3],[22.5],[13.7],[46.33],[18.5],[15.0],[7.5],[7.0],[10.1],[15.3],[8.5],[8.5],[4.5],[8.5],[8.0],[5.7],[10.5],[4.5],[62.66],[5.5],[6.9],[5.0],[14.9],[57.33],[12.1],[4.9],[7.7],[8.1],[11.7],[17.3],[37.83],[8.1],[6.5],[11.7],[49.57],[27.0],[9.5],[11.3],[6.5],[12.1],[8.5],[11.7],[10.1],[4.1],[9.7],[7.5],[5.0],[8.5],[28.9],[12.1],[6.9],[12.5],[8.9],[6.9],[8.5],[5.7],[10.5],[6.9],[3.3],[21.0],[4.1],[5.3],[5.3],[6.1],[9.7],[7.0],[17.0],[3.3],[8.1],[3.5],[25.8],[5.7],[10.5],[7.5],[11.3],[7.7],[6.5],[4.1],[5.7],[7.0],[25.5],[56.8],[5.3],[45.0],[8.1],[5.7],[9.5],[8.5],[5.5],[8.1],[11.5],[6.5],[14.1],[15.7],[4.5],[20.9],[9.7],[11.0],[33.83],[7.3],[6.0],[14.5],[22.9],[9.5],[6.9],[6.5],[17.83],[6.5],[8.1],[17.0],[5.7],[17.0],[8.5],[18.1],[17.5],[10.5],[25.0],[6.0],[7.7],[6.5],[6.5],[11.0],[6.1],[5.0],[14.5],[5.7],[36.1],[12.1],[10.9],[10.5],[15.3],[6.5],[9.3],[6.5],[12.0],[6.0],[5.7],[10.1],[9.3],[22.1],[9.0],[12.5],[22.5],[10.1],[20.0],[9.0],[8.0],[11.7],[13.5],[5.5],[4.5],[7.3],[30.1],[13.0],[52.9],[16.1],[15.3],[13.5],[3.3],[3.5],[7.5],[6.0],[10.5],[6.1],[20.5],[8.1],[6.0],[6.5],[4.5],[14.5],[20.0],[4.1],[11.7],[8.1],[9.3],[7.7],[7.0],[17.3],[8.5],[5.7],[4.5],[12.5],[4.5],[12.9],[7.7],[8.5],[11.3],[4.6],[15.0],[31.0],[4.1],[14.1],[8.5],[4.9],[15.7],[15.5],[11.0],[35.33],[5.3],[57.33],[8.9],[8.5],[11.0],[15.5],[17.5],[3.7],[4.9],[6.5],[7.3],[12.5],[6.5],[4.9],[10.1],[7.5],[7.5],[6.0],[17.3],[9.7],[15.0],[4.5],[11.0],[6.5],[5.3],[4.9],[8.9],[6.5],[7.5],[39.8],[7.7],[4.5],[22.1],[20.5],[7.3],[7.7],[8.5],[4.1],[8.5],[12.5],[10.5],[6.1],[6.5],[5.0],[4.0],[8.1],[4.1],[8.0],[13.5],[5.7],[16.9],[7.5],[7.3],[6.5],[8.5],[4.5],[5.0],[4.5],[11.5],[42.04],[18.5],[38.9],[11.5],[7.5],[4.9],[10.0],[8.1],[9.5],[6.9],[6.5],[6.5],[8.1],[12.0],[4.5],[9.0],[15.87],[8.5],[10.0],[11.3],[6.5],[12.5],[7.3],[6.1],[13.3],[16.5],[17.3],[8.1],[7.3],[7.5],[8.5],[10.0],[3.3],[7.0],[12.1],[8.5],[7.5],[88.0],[26.25],[20.5],[8.5],[15.5],[6.9],[35.0],[9.5],[6.1],[8.9],[11.3],[3.7],[13.3],[8.9],[9.5],[12.0],[19.0],[8.9],[49.8],[8.9],[5.3],[9.7],[7.3],[6.1],[13.0],[7.0],[5.0],[20.1],[5.3],[28.5],[4.5],[12.1],[3.7],[9.3],[15.0],[12.5],[10.1],[7.0],[7.3],[7.5],[30.5],[8.5],[14.5],[18.5],[7.3],[9.7],[3.7],[4.0],[8.0],[10.5],[8.5],[9.5],[17.0],[7.7],[14.1],[16.9],[6.5],[22.5],[10.5],[7.7],[13.0],[13.0],[6.0],[5.7],[7.0],[3.7],[21.5],[7.5],[10.5],[6.5],[15.5],[6.1],[13.5],[23.5],[6.0],[5.3],[11.3],[14.5],[7.0],[6.9],[28.5],[7.3],[6.5],[4.5],[10.0],[15.0],[57.33],[17.0],[16.0],[27.0],[10.5],[11.5],[6.9],[15.0],[6.0],[12.9],[12.0],[5.0],[4.0],[13 ...

# %% [markdown]
# 4.3 Histrogram plot of <b><em>fare</em></b> price

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(15, 4))

plt.hist(rn_sample_df['amount'], bins=100, color='#20beff')
plt.xlabel("fare ($)")
plt.title("Histrogram plot of fare ($)")
plt.show()

# %% [markdown]
# 4.4 Barplot for visualizing the <em><b>number of rides</b></em> in the following years

# %%
year_insight = rn_sample_df.year.value_counts()

plt.figure(figsize=(15, 4))
sns.barplot(data=rn_sample_df, x=year_insight.index, y=year_insight.values, palette=palette)
plt.ylabel("Number of rides")
plt.xlabel("Years")
plt.show()

# %% [markdown]
# 4.4 Traffic in the <em><b>year 2012</b></em>

# %%
year2012_insight = rn_sample_df[rn_sample_df['year'] == 2012]

# %%
xlim = [-74.03, -73.85]
ylim = [40.70, 40.85]

year2012_traffic_insight = year2012_insight.copy()
year2012_insight = year2012_insight[(year2012_insight.longitude_of_pickup > xlim[0]) & (year2012_insight.longitude_of_pickup  < xlim[1])]
year2012_insight = year2012_insight[(year2012_insight.longitude_of_dropoff > xlim[0]) & (year2012_insight.longitude_of_dropoff < xlim[1])]
year2012_insight = year2012_insight[(year2012_insight.latitude_of_pickup > ylim[0]) & (year2012_insight.latitude_of_pickup < ylim[1])]
year2012_insight = year2012_insight[(year2012_insight.latitude_of_dropoff > ylim[0]) & (year2012_insight.latitude_of_dropoff < ylim[1])]

# %%
plt.figure(figsize = (15, 7))

plt.subplot(1, 2, 1)
plt.plot(year2012_insight.longitude_of_dropoff, year2012_insight.latitude_of_dropoff, 'o', alpha = .5, markersize = 2, color="#fff", markeredgecolor='#000', markeredgewidth=1.5)
plt.plot(year2012_insight.longitude_of_dropoff, year2012_insight.latitude_of_dropoff, '.', alpha = .8, markersize = .5, color="red")
plt.legend(['Dropoff Points', "Pickup Points"])
plt.xlabel("\nTraffic in the Year 2012 \n(Black --> Dropoff Points, Red --> Pickup Points)")
plt.grid(False)

plt.subplot(1, 2, 2)
days_list = {'monday' : 0, 'tuesday' : 1, 'wednesday' : 2, 'thursday' : 3, 'friday' : 4, 'saturday' : 5, 'sunday' : 6}
weeklyTraffic = year2012_insight['weekday'].value_counts()
plt.pie(weeklyTraffic.values, labels=days_list, autopct="%.2f%%", explode=[0.1, 0.1, 0.1, 0, 0, 0, 0], colors=palette)
plt.xlabel("\nAmount of weekdays of Year 2012")
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier

# %%
loc_df = pd.DataFrame()
loc_df['longitude'] = year2012_insight.longitude_of_dropoff 
loc_df['latitude'] = year2012_insight.latitude_of_dropoff


kmeans = KMeans(n_clusters=15, random_state=2, n_init = 10).fit(loc_df)
loc_df['label'] = kmeans.labels_

plt.figure(figsize = (10, 10))
for label in loc_df.label.unique():
    plt.plot(loc_df.longitude[loc_df.label == label],loc_df.latitude[loc_df.label == label],'.', alpha = 1, markersize = 0.8)

plt.title('Clusters of New York of year 2012')
plt.show()

# %% [markdown]
# 4.4 (b) Lets see the <em><b>peaks days</b></em> with their <em><b>rush hours</b></em> of year 2012

# %%
def visualize_peakDaysF(day, color='r'):
    year2012_monday_insight = year2012_insight[year2012_insight["weekday"] == day]
    day_name = list(days_list.keys())[day]
    plt.figure(figsize = (15, 70))
    
    max_pickup, max_pgcnt = 0, 0
    
    for hrs in range(24):
        specDay_traffic = year2012_monday_insight[year2012_monday_insight['hour'] == hrs]
        pickup = len(specDay_traffic)
        pgn_cnt = specDay_traffic["no_of_passenger"].sum()
        
        
        max_pickup = max(max_pickup, pickup)
        max_pgcnt = max(max_pgcnt, pgn_cnt)


        longitude = list(specDay_traffic.longitude_of_pickup) + list(specDay_traffic.longitude_of_dropoff )
        latitude = list(specDay_traffic.latitude_of_pickup) + list(specDay_traffic.latitude_of_dropoff)
        plt.subplot(24, 6, hrs+1)

        plt.title("\nHour: " + str(hrs) + " [pickup="+ str(pickup)+",\npassengers count="+ str(pgn_cnt)+"] ", fontsize=12)

        plt.grid(False)
        plt.xticks([])
        plt.yticks([])
        plt.plot(longitude,latitude,'.', alpha = 0.6, markersize = 10, color=color)

#         break
    plt.suptitle("\n"+ day_name.capitalize() +" (max pickups=" + str(max_pickup) + ", max passengers=" + str(max_pgcnt) + ")\n\n\n\n\n\n", fontsize=20)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# 4.4 (b1) Visualize the rush hours for <b><em>monday</em></b>

# %%
visualize_peakDaysF(0, color='#4856fb')

# %% [markdown]
# 4.4 (b2) Visualize the rush hours for <b><em>Tuesday</em></b>

# %%
visualize_peakDaysF(1, color='#10a2f0')

# %% [markdown]
# 4.4 (b2) Visualize the rush hours for <b><em>Sunday</em></b>

# %%
visualize_peakDaysF(6, color='#ffa256')

# %% [markdown]
# 4.4 (c)\ Histrogram plot for the <b><em>distances(mile)</em></b> travelled
# This histrogram gives us a veiw that most of the ride taken was a short ride

# %%
year2012_insight.distance.hist(bins=30, figsize=(15,4), color='#20beff')
plt.xlabel("distances(mile)")
plt.title("Histrogram plot of distance(mile)")
plt.show()

# %%
year2012_insight.groupby('no_of_passenger')['distance', 'amount'].mean()
# Out:
#                  distance     amount
# no_of_passenger
# 0                2.502172  10.811111
# 1                1.531293   9.695276
# 2                1.879781  11.235885
# 3                1.480242   9.996226
# 4                1.480231   9.506667
# 5                1.380788   8.686667
# 6                1.446574  10.000000

# %%
print("Average $USD/Mile : {:0.2f}".format(year2012_insight.amount.sum()/year2012_insight.distance.sum()))
# Out:
# Average $USD/Mile : 6.28

# %% [markdown]
# 4.4 (d) Scatter plot visualization between <em><b>Fare(in $USD)</b></em> vs  <em><b>Distance(in Miles)</b></em> of year 2012

# %%
plt.figure(figsize=(15,4))

plt.scatter(year2012_insight.amount, year2012_insight.distance, c=year2012_insight.amount, 
            cmap=plt.cm.rainbow, alpha=0.8, s=1, marker=".")
plt.xlabel("Fare(in $USD)")
plt.ylabel("Distance(in Miles)")
plt.title("Scatter plot Fare(in $USD) vs Distance(in Miles)\n")
ol = plt.grid(False)
plt.colorbar(ol)
plt.show()

# %% [markdown]
# By seeing this data we can sumarize:
#
# 1. There are trips with zero distance but with a non-zero fare. Could this be trips from and to the same location? Predicting these fares will be difficult as there is likely not sufficient information in the dataset.
#
# 2. Overall there seems to be a (linear) relation between distance and fare.
#
# 3. Initial charge for most rides is $2.50 upon entry
#
# 4. And it also seems that someone has paid way too much (>120$)

# %%
# remove datapoints with distance < 0.05 miles

print("Old size: ", len(year2012_insight))
train_df = year2012_insight[year2012_insight.distance >= 0.05]

print("New size: ", len(train_df))
# Out:
# Old size:  1445
# New size:  1410

# %% [markdown]
# ## 5. Model (for the year 2012 only)
# <div style="background:#ffbf00; height:3px; width:70%; margin-left:-10px"></div>
# <em><b>Due too the large volume of dataset this notebook was constantly crashing, so in here we are only gonna use the data of year 2012 </b></em>

# %% [markdown]
# 5.1 Generate the <em><b>test</b></em> data

# %%
model_data = train_df[['year', 'hour', 'distance', 'no_of_passenger', 'amount']]

# %%
model_data.head()
# Out:
#        year  hour  distance  no_of_passenger  amount
# 26147  2012     2  4.920778                1    18.0
# 34643  2012    16  3.486243                2    14.5
# 5224   2012    20  0.966453                1     5.0
# 30024  2012    19  0.106451                1     4.9
# 40788  2012    20  0.196786                1     4.5

# %% [markdown]
# 5.2 Train, test split of the datasets

# %%
X = model_data[['year', 'hour', 'distance', 'no_of_passenger']]
y = model_data[['amount']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# 5.3 Model Run

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

model_lin = Pipeline((
        ("standard_scaler", StandardScaler()),
        ("lin_reg", LinearRegression()),
    ))
model_lin.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standard_scaler', StandardScaler()),
#                 ('lin_reg', LinearRegression())])

# %% [markdown]
# 5.4 Model Score

# %%
from sklearn.metrics import r2_score

y_test_pred = model_lin.predict(X_test)
score = r2_score(y_test, y_test_pred)
print("The accuracy of our model is {}%".format(round(score, 2) *100))
# Out:
# The accuracy of our model is 33.0%
